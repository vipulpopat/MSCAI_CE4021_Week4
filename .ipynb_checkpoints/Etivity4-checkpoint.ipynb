# %% [markdown]
# #Student Name: Garret Molloy
# #Student ID: 9021906

# %%
""" Starting point of code is Etivity3 code Branch Niall-Tierney
    Having REviewed Niall's code for Eivity3 - I am updating his code for Etivity4 """


mul_matrix_1 = ((1,2), (3,4), (5,6))
mul_matrix_2 = ((2,3,4), (5,4,6))
sub_matrix_1 = ((2,3,4), (5,4,6))
sub_matrix_2 = ((4,7,5), (2,3,5))
vector1 = [2,5,7]

m3 = [[4,1,3], [2,-5, 7]]
m4 = [[-2,3, 1, 2], [-4,-2, 5, 6], [5,1, 7, 8]]


class Matrix:
    def __init__(self, *args, **kwargs):
        """ 
        To create an instance of MAtrix we can pass in either:
        
        1. Matrix(rows = m, columns = n)
        we can pass in m and n of Type int > 0
        we will create a matrix of size (m x n)
        with all elements in the matrix set to 0 

        2. Matrix(cells = my_list) 
        we can pass in the List that defines the Matrix
        my_list is of Type list 

        3. Matrix(vector = my_vector)
        We can pass in a vector which will be of Type list
        We will convert the vecotr into a class MAtrix so it can use
        the multiply, add and subtract methods of the class """

        self.rows = kwargs.get('rows', 0)
        self.columns = kwargs.get('columns', 0)
        self.cells = kwargs.get('cells')
        
        # 1. Matrix(rows = m, columns = n)
        if(self.rows > 0  and self.columns > 0):
            # create a blank output matrix for returning on completion
            self.cells  = []
            self.cells = [0] * self.rows       # Output Rows = Rows_m1
            for i in range(self.rows):
                self.cells[i] = [0] * self.columns  # Output Cols = Cols_m2   
                
        # 2. Matrix(cells = my_list)
        elif(type(self.cells) is list):
            self.rows = len(self.cells)
            self.columns = len(self.cells[0])
            
        # 3. Matrix(vector = my_vector)
        else:
            vector = kwargs.get('vector')
        
            if (type(vector) is not list):
                raise ValueError("Cannot create Matrix")
            self.columns = 1
            self.rows = len(vector)
            # vector passed in co create an empty matrix with 1 column   
            self.cells = Matrix(rows=len(vector), columns = 1).cells
            for i in range(self.rows):
                self.cells[i][0] = vector[i]
            
    def multiply(self, matrix2):
        """ Multiplying this Matrix by the Matrix passed in"""
        # Check these Matrices can be multiplied
        if(self.columns!=matrix2.rows):
            raise ValueError("Rule 1 Failed: Cannot do Multiplication")
        
        result_matrix = Matrix(rows = self.rows, columns = matrix2.columns)
        
        for output_row_number in range(self.rows): # Output Rows = selff.rows
            c_string = ''
            for output_col_number in range(matrix2.columns): # Output Cols = Cols_m2
                e = 0
                for i in range(self.columns):
                    e += self.cells[output_row_number][i]*matrix2.cells[i][output_col_number]
                result_matrix.cells[output_row_number][output_col_number] = e
                c_string = c_string + str(e) + ',  '
            print(c_string[:-3])
        print('_ _ _ _ _ _ _ _ _ _ _ ')
        return result_matrix  # return result as a Matrix
    
    def print(self):
        for i in range(self.rows):
            row_string = ("[")
            for j in range (len(matrix[i])):
                row_string +=("{0:>6},".format(matrix[i][j]))
            print(row_string[:-1],"]") # Thanks Niall for remove last comma without needing position check

'''
def mul_vec_mat(vec, mat):
    string = ''
    for r in range(len(mat[0])):
        e = 0
        for c in range(len(vec)):
            e += vec[c] * mat[c][r]
        string = string + str(e)+',  '
    print(string[:-3])
    print('_ _ _ _ _ _ _ _ _ _ _ ')


def matrix_cal(m1, m2, operation):
    # create a blank output matrix for returning on completion
    result =[0]*len(m1)       # Output Rows = Rows_m1
    for i in range(len(m1)):
        result[i] = [0] * len(m1[0]) # Output Cols = Cols_m1
        
    for r in range(len(m1)):
        string = ''
        for c in range(len(m1[0])):
            if operation == '-':e = m1[r][c] - m2[r][c]
            if operation == '+': e = m1[r][c] + m2[r][c]
            string = string + str(e) +',  '
        print(string[:-3])
    print('_ _ _ _ _ _ _ _ _ _ _ ')

'''
def main():
    '''
    mul_vec_mat(vector1, mul_matrix_1)
    matrix_cal(sub_matrix_1, sub_matrix_2, '+')
    matrix_mmul(mul_matrix_1, mul_matrix_2)
    answer = matrix_mmul(m3, m4)
    print(answer)
    
    #prove Ax(BxC) == (AxB)xC
    A = [[2,3], [4,5]]
    B = [[1,0], [-1,-2]]
    C = [[-3, -5], [2,1]]
    # Ax(BxC)
    temp = matrix_mmul(B,C)
    answer1 = matrix_mmul(A,temp)
    # (AxB)xC
    temp = matrix_mmul(A,B)
    answer2 = matrix_mmul(temp,C)    

    print("Is Ax(BxC) == (AxB)xC ? This is ", answer1==answer2)
    '''
    v1_matrix = Matrix(vector = vector1)
    print(v1_matrix.cells)
    mmm111 = Matrix(rows=2, columns=3)
    matrix_m1 = Matrix(cells=m3)
    print("m1 rows:", matrix_m1.rows)
    print("m1 columns:", matrix_m1.columns)
    print("v1 rows:", v1_matrix.rows)
    print("v1 columns:", v1_matrix.columns)
    
    matrix_m2 = Matrix(cells=m4)
    print(matrix_m1.multiply(matrix_m2).cells)
    print(matrix_m1.multiply(v1_matrix).cells)
    
if __name__ == '__main__':
    main()
# Out:
# [[2], [5], [7]]
# m1 rows: 2
# m1 columns: 3
# v1 rows: 3
# v1 columns: 1
# 3,  13,  30,  38
# 51,  23,  26,  30
# _ _ _ _ _ _ _ _ _ _ _
# [[3, 13, 30, 38], [51, 23, 26, 30]]
# 34
# 28
# _ _ _ _ _ _ _ _ _ _ _
# [[34], [28]]
