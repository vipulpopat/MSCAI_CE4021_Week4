# %% [markdown]
# #Student Name: Vipul Popat
# #Student ID:   18195121

# %% [markdown]
# ***Task***
# With the final version of the code from the peer you selected in E-tivity 3 as a starting point, create a class that contains one tensor and provides the following methods:
#
# I have used the final version of Etivity Code of Brian Parle (Version ad6233c7390ebe909565f03c0594f5fb56213ec3) in order to get this class done.
#
# - Calculate the size of the tensor as a 2D tuple
# - Sum/subtract the tensor with another tensor of suitable size
# - Multiply the tensor with a tensor of suitable size
# - Calculate the determinant of the tensor, but only for tensors of size 2x2 (matrix)
# - Calculate the inverse of the tensor, but only for tensors of size 2x2
# - Calculate the cross product of the tensor with another tensor of suitable size
#
# N.B.:
#
# Use the Jupyter Notebook provided in the repository for week 4.
# Limit your code to use for tensors of rank 1 and 2 (vectors and matrices)
# Write your code without the use of imported modules.
# Provide suitable exception handling to prevent the above operations from being used on unsuitable tensors.
# Test your code with one example for each of the following scenarios:
# - sum of a 4x4 with a 4x4 matrix
# - multiplication of a 4x4 with a 4x4 matrix
# - multiplication of a 4x4 matrix with a suitable vector
# - determinant of a 2x2 matrix
# - inverse of a 2x2 matrix
# - cross-product of 2 suitable tensors
#
# GIT commit your tested code and push to your remote branch. Submit a message to the E-tivity 4: Matrix Determinant, Inverse and Cross-product forum with a detailed description of how you have implemented the above described functionality and the name of your git branch. As part of your post, provide calculations for the determinant, inverse and cross product methods with the tensors you chose for your tests. You may add these calculations to your post using the formula editor or as a scan of handwritten notes.

# %%
class Matrix:
    # instance variables
    m_tuples = []
    dimension = (0,0)
    dimension_2x2 = (2,2)
    dimension_3x1 = (3,1)
    
    def __init__(self, m_tuples):
        self.m_tuples = m_tuples
        self.dimension = self.matrix_get_size()

    def __add__(self, other_matrix):
        return self.matrix_add_or_subtract(other_matrix, Matrix.fn_add)

    def __sub__(self, other_matrix):
        return self.matrix_add_or_subtract(other_matrix, Matrix.fn_subtract)

    def __mul__(self, other_matrix):
        if isinstance(other_matrix, (int, float)):
            return self.scalar_multiplication(other_matrix)
        else:
            return self.matrix_multiplication(other_matrix)
    
    def matrix_get_size(self):
        """
        Matrix size is (number of rows, number of columns)
        """
        return (len(self.m_tuples), len(self.m_tuples[0]))    
    
    """ had to make this method static in order to reuse this in the functions """
    @staticmethod
    def fn_add(x,y):
        return x + y
    
    """ had to make this method static in order to reuse this in the functions """
    @staticmethod
    def fn_subtract(x,y):
        return x - y    
    
    def scalar_multiplication(self, other):
        """
        Purpose: multiple a matrix with a scalar
        """
        result = []
        for tup in self.m_tuples:
            result.append(tuple([x*other for x in tup]))
        return Matrix(tuple(result))
            

    def matrix_multiplication(self, other):
        """
        Purpose: multiple 2 matrices or a matrix and vector
        """
        if not self.compatible_matrix_size(other, "multiply"):
            return []
        
        m1_rowcount = len(self.m_tuples)
        m1_colcount = len(self.m_tuples[0])
        m2_colcount = len(other.m_tuples[0])
        new_matrix = []
        for m1_rowindex in range(m1_rowcount):
            #for this row in matrix1, multiple each rowitem by each item in the corresponding column in matrix2
            new_row = []
            for m2_colindex in range(m2_colcount):
                #for this column in matrix2, sum the product of each row item with each column item
                cell_sum = 0
                for m1_colindex in range(m1_colcount):
                    #iterate through each item in the matrix1 row
                    cell_sum += self.m_tuples[m1_rowindex][m1_colindex] * other.m_tuples[m1_colindex][m2_colindex]
                #add this item to the new matrix row
                new_row.append (cell_sum)
            #add the new matrix row to the output matrix
            new_matrix.append (tuple(new_row))
        return Matrix(tuple(new_matrix))
    
    def matrix_add_or_subtract(self, other, fn_operate):
        """
        Purpose: Add or subtract 2 matrices. Add or subtract function is passed as argument
        """
        if not self.compatible_matrix_size( other, "add_or_subtract"):
            return []
    
        new_matrix = []
        for rowindex, row in enumerate(self.m_tuples):
            new_row = []
            for colindex, col in enumerate(self.m_tuples[rowindex]):
                new_row.append (fn_operate(row[colindex] , other.m_tuples[rowindex][colindex]))
            new_matrix.append (tuple(new_row))
        return tuple(new_matrix)

    def compatible_matrix_size(self, other, op):
        if op == "multiply":
            if self.dimension[0] != other.dimension[1]:
                #matrix 1 does not have the same number of columns as matrix 2, so incompatible
                return False
        elif op == "add_or_subtract":
            if self.dimension != other.dimension:
                #matrices do not have same number of rows and columns, so incompatible
                return False
        #no errors, so compatible
        return True

    def __matmul__(self, other):
        self.__mul__(other)

    def __str__(self):
        return str(self.m_tuples)
    
    def __eq__(self, other_matrix):
        return self.m_tuples == other_matrix.m_tuples
    
    def determinant(self):
        if self.dimension != Matrix.dimension_2x2:
            raise ValueError("This function is only for 2x2 tensor")
        return self.m_tuples[0][0] * self.m_tuples[1][1] - self.m_tuples[0][1] * self.m_tuples[1][0]

    def inverse(self):
        if self.dimension != Matrix.dimension_2x2:
            raise ValueError("This function is only for 2x2 tensor")
        multiplier = 1 / self.determinant()
        new_m_tuple = ((self.m_tuples[1][1],self.m_tuples[0][1] * -1),(self.m_tuples[1][0] * -1, self.m_tuples[0][0]))
        return Matrix(new_m_tuple) * multiplier
    
    def cross_product(self, other):
        # Calculate the cross product of the tensor with another tensor of suitable size
        #This implementation only works with vectors with rank 3, other rank vectors other than 7 do not have a cross product

        (nr_n, nc_n) = self.dimension
        (nr_m, nc_m) = other.dimension

        if self.dimension != Matrix.dimension_3x1 and other.dimension != Matrix.dimension_3x1:
            raise ValueError("Cross product is only implemented 3d vectors")

        v1 = self.m_tuples
        v2 = other.m_tuples
        m1 = Matrix(((v1[1][0], v2[1][0]),(v1[2][0], v2[2][0])))
        m2 = Matrix(((v1[2][0], v2[2][0]),(v1[0][0], v2[0][0])))
        m3 = Matrix(((v1[0][0], v2[0][0]),(v1[1][0], v2[1][0])))
        return Matrix(((m1.determinant(),),(m2.determinant(),),(m3.determinant(),)))
    
    
# Test matrices
matrix_1 = Matrix(((7, 4, -3, 2), (-1, 0, 6, 1), (3, 9, 2, 5), (8, 5, 9, -6)))
matrix_2 = Matrix(((-4, 9, -7, 4), (-3, 6, 0, 8), (0, -5, -2, 1), (2, 1, 3, -8)))
matrix_3 = Matrix(((5,), (-4,), (3,), (-2,)))

# Sum, Subtract and Multiply 4x4 Matrices
print("matrix1 + matrix_2 = ", str(matrix_1 + matrix_2))
print("matrix1 - matrix_2 = ", str(matrix_1 - matrix_2))
print("matrix1 * matrix_2 = ", str(matrix_1 * matrix_2))

# Multiply Matrix by Vector and Vector by Matrix
print("matrix2 * matrix_3 = ", str(matrix_2 * matrix_3))

matrix_2x2_m1 = ((2,4),(3,-1))
# Print determinant and inverse of a matrix
print("Determinant of matrix_2x2_m1 = ", Matrix(matrix_2x2_m1).determinant())
print("Inverse of matrix_2x2_m1 = ", Matrix(matrix_2x2_m1).inverse())

#Cross product
matrix_3x1_1=Matrix(((1,),(2,),(-1,)))
matrix_3x1_2=Matrix(((-4,),(1,),(-2,)))
print("Cross product of matrix_3x1_1 x matrix_3x1_2 = ", str(matrix_3x1_1.cross_product(matrix_3x1_2)))
# Out:
# matrix1 + matrix_2 =  ((3, 13, -10, 6), (-4, 6, 6, 9), (3, 4, 0, 6), (10, 6, 12, -14))
# matrix1 - matrix_2 =  ((11, -5, 4, -2), (2, -6, 6, -7), (3, 14, 4, 4), (6, 4, 6, 2))
# matrix1 * matrix_2 =  ((-36, 104, -37, 41), (6, -38, -2, -6), (-29, 76, -10, 46), (-59, 51, -92, 129))
# matrix2 * matrix_3 =  []
# Determinant of matrix_2x2_m1 =  -14
# Inverse of matrix_2x2_m1 =  ((0.07142857142857142, 0.2857142857142857), (0.21428571428571427, -0.14285714285714285))
# Cross product of matrix_3x1_1 x matrix_3x1_2 =  ((-3,), (6,), (9,))
